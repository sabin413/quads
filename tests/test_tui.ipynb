# %%
import pandas as pd

df = pd.read_pickle(
    "~/JupyterLinks/nobackup/quads_results/GEOSFP/2024/02/01/"
    "quads_results_geosfp_2024_02_01_reference_date_2023-01.pkl"
)

#print(df)

# %%
#print(df.iloc[2])

# %%
df_sorted = df.sort_values(by="no_of_total_violations", ascending=False)

#print(df_sorted.head())

# %%
print(df_sorted.iloc[2000])
# Out:
# id_string                                tavg1_2d_slv_Nx|TROPPT|None|Strat5
# no_of_violations_left                                                   155
# no_of_violations_right                                                    0
# no_of_total_violations                                                  155
# fence_low                                                       6262.284174
# fence_high                                                     34056.354883
# quantile_values           [7057.8571263520835, 7255.205874355769, 7255.5...
# q_list                    [1e-07, 1e-06, 1e-05, 0.0001, 0.001, 0.01, 0.1...
# Name: 79539, dtype: object
